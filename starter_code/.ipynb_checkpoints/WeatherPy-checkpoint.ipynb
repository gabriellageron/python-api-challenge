# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 642

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
#weather_api_key = weather_api_key.weather_api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=itarema
# Processing Record 2 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=jamestown
# Processing Record 3 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=cape town
# Processing Record 4 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=provideniya
# Processing Record 5 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=mount isa
# Processing Record 6 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=thinadhoo
# Processing Record 7 | Puerto Rondon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=puerto rondon
# Processing Record 8 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bluff
# Processing Record 9 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ushuaia
# Processing Record 10 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=castro
# Processing Record 11 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=vestmannaeyjar
# Processing Record 12 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=pisco
# Processing Record 13 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kahului
# Processing Record 14 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=zhigansk
# Processing Record 15 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=new norfolk
# Processing Record 16 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=busselton
# Processing Record 17 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=hobart
# Processing Record 18 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=punta arenas
# Processing Record 19 | Strathmore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=strathmore
# Processing Record 20 | Ekuvukeni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ekuvukeni
# Processing Record 21 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=fortuna
# Processing Record 22 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bethel
# Processing Record 23 | Barabinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=barabinsk
# Processing Record 24 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=beloha
# Processing Record 25 | Timbuktu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=tombouctou
# Processing Record 26 | Clarksburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=clarksburg
# Processing Record 27 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=hithadhoo
# Processing Record 28 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=san cristobal
# Processing Record 29 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=albany
# Processing Record 30 | Anzio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=anzio
# Processing Record 31 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=clyde river
# Processing Record 32 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=qaanaaq
# Processing Record 33 | Marathon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=marathon
# Processing Record 34 | Neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=neiafu
# Processing Record 35 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sao filipe
# City not found. Skipping...
# Processing Record 36 | Kurtamysh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kurtamysh
# Processing Record 37 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kapaa
# Processing Record 38 | Sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sabang
# Processing Record 39 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=vaini
# City not found. Skipping...
# Processing Record 40 | Zalantun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=zalantun
# Processing Record 41 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ostrovnoy
# Processing Record 42 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=butaritari
# City not found. Skipping...
# Processing Record 43 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=mount gambier
# Processing Record 44 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kununurra
# Processing Record 45 | Dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=dhidhdhoo
# Processing Record 46 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=mahebourg
# Processing Record 47 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=vardo
# Processing Record 48 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kaitangata
# Processing Record 49 | Shakawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=shakawe
# Processing Record 50 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=avarua
# City not found. Skipping...
# Processing Record 51 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=hermanus
# Processing Record 52 | Yaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=yaya
# Processing Record 53 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=lagoa
# Processing Record 54 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=port alfred
# Processing Record 55 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=dikson
# Processing Record 56 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=norman wells
# Processing Record 57 | Moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=moron
# Processing Record 58 | Bradford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bradford
# Processing Record 59 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=saint-philippe
# Processing Record 60 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bredasdorp
# Processing Record 61 | Santa Fe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=santa fe
# Processing Record 62 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=vostok
# Processing Record 63 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=longyearbyen
# Processing Record 64 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=coquimbo
# Processing Record 65 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=tautira
# Processing Record 66 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bambous virieux
# Processing Record 67 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=acapulco
# City not found. Skipping...
# Processing Record 68 | Dosso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=dosso
# Processing Record 69 | Choma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=choma
# Processing Record 70 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=namatanai
# Processing Record 71 | Roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=roald
# Processing Record 72 | Estelle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=estelle
# Processing Record 73 | Meiktila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=meiktila
# Processing Record 74 | Maoming
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=maoming
# Processing Record 75 | Upington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=upington
# Processing Record 76 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kodiak
# Processing Record 77 | Khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=khandyga
# Processing Record 78 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=flinders
# Processing Record 79 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=saskylakh
# Processing Record 80 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=airai
# Processing Record 81 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=vao
# Processing Record 82 | Jinchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=jinchang
# City not found. Skipping...
# Processing Record 83 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ribeira grande
# Processing Record 84 | Urdoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=urdoma
# Processing Record 85 | Nicoya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=nicoya
# Processing Record 86 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=barrow
# Processing Record 87 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=chuy
# Processing Record 88 | Birakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=birakan
# City not found. Skipping...
# Processing Record 89 | Artyom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=artyom
# Processing Record 90 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=rikitea
# Processing Record 91 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=mataura
# Processing Record 92 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=torbay
# Processing Record 93 | Terrace
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=terrace
# Processing Record 94 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=deputatskiy
# Processing Record 95 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=luderitz
# Processing Record 96 | Kasongo-Lunda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kasongo-lunda
# Processing Record 97 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=grindavik
# Processing Record 98 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=poum
# Processing Record 99 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=alice springs
# Processing Record 100 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=pevek
# Processing Record 101 | Sindor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sindor
# Processing Record 102 | Velyka Bahachka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=velyka bahachka
# Processing Record 103 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=esperance
# Processing Record 104 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kavieng
# City not found. Skipping...
# Processing Record 105 | Axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=axim
# Processing Record 106 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=puerto ayora
# Processing Record 107 | Quattro Castella
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=quattro castella
# Processing Record 108 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=port-cartier
# Processing Record 109 | Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sale
# Processing Record 110 | Moyale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=moyale
# Processing Record 111 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=nemuro
# Processing Record 112 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=coihaique
# Processing Record 113 | Palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=palmer
# Processing Record 114 | Porto Novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=porto novo
# Processing Record 115 | Road Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=road town
# Processing Record 116 | Kangaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kangaba
# Processing Record 117 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=tuktoyaktuk
# Processing Record 118 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=tasiilaq
# City not found. Skipping...
# Processing Record 119 | Santa Cruz de Tenerife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=santa cruz de tenerife
# Processing Record 120 | Batagay-Alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=batagay-alyta
# Processing Record 121 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=nanortalik
# Processing Record 122 | Paranaiba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=paranaiba
# Processing Record 123 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=alofi
# Processing Record 124 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=saint george
# Processing Record 125 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=lebu
# Processing Record 126 | Pervomayskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=pervomayskiy
# Processing Record 127 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=iqaluit
# Processing Record 128 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=cayenne
# Processing Record 129 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=cherskiy
# City not found. Skipping...
# Processing Record 130 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=vila franca do campo
# Processing Record 131 | Angoram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=angoram
# Processing Record 132 | Manado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=manado
# City not found. Skipping...
# Processing Record 133 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=lorengau
# Processing Record 134 | Pokhara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=pokhara
# Processing Record 135 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=camacha
# Processing Record 136 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=tuatapere
# City not found. Skipping...
# Processing Record 137 | Boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=boyolangu
# Processing Record 138 | Bhadrachalam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bhadrachalam
# Processing Record 139 | Broken Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=broken hill
# Processing Record 140 | Enshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=enshi
# Processing Record 141 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=port blair
# Processing Record 142 | Zaysan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=zaysan
# Processing Record 143 | Baiyin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=baiyin
# Processing Record 144 | Skibbereen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=skibbereen
# Processing Record 145 | Sunbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sunbury
# Processing Record 146 | Campbell River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=campbell river
# Processing Record 147 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=atuona
# City not found. Skipping...
# Processing Record 148 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=haines junction
# Processing Record 149 | Zhanaozen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=zhanaozen
# Processing Record 150 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=labuhan
# Processing Record 151 | Rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=rundu
# Processing Record 152 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=husavik
# Processing Record 153 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=aklavik
# City not found. Skipping...
# Processing Record 154 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=manokwari
# Processing Record 155 | Boende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=boende
# Processing Record 156 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=nikolskoye
# Processing Record 157 | Dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=dwarka
# Processing Record 158 | Ust-Nera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ust-nera
# Processing Record 159 | Suntar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=suntar
# Processing Record 160 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=hambantota
# Processing Record 161 | Nongstoin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=nongstoin
# Processing Record 162 | Waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=waipawa
# Processing Record 163 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=anadyr
# Processing Record 164 | Barra Patuca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=barra patuca
# Processing Record 165 | San Luis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=san luis
# City not found. Skipping...
# Processing Record 166 | Clovis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=clovis
# Processing Record 167 | Storsteinnes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=storsteinnes
# Processing Record 168 | Washington DC.
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=washington
# Processing Record 169 | Saint-Georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=saint-georges
# Processing Record 170 | Kankan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kankan
# Processing Record 171 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=cidreira
# Processing Record 172 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=arlit
# Processing Record 173 | Nova Olimpia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=nova olimpia
# Processing Record 174 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kirakira
# Processing Record 175 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=cabo san lucas
# Processing Record 176 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=dunedin
# Processing Record 177 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=port elizabeth
# Processing Record 178 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=henties bay
# Processing Record 179 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=victoria
# Processing Record 180 | Inyonga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=inyonga
# Processing Record 181 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=codrington
# Processing Record 182 | Yarada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=yarada
# Processing Record 183 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sioux lookout
# Processing Record 184 | Dolinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=dolinsk
# Processing Record 185 | Sijunjung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sijunjung
# Processing Record 186 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=komsomolskiy
# Processing Record 187 | Siva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=siva
# Processing Record 188 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=taoudenni
# Processing Record 189 | Ventspils
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ventspils
# Processing Record 190 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=khatanga
# Processing Record 191 | Todos Santos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=todos santos
# Processing Record 192 | Jawhar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=jawhar
# Processing Record 193 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=la ronge
# Processing Record 194 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=hami
# Processing Record 195 | Nola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=nola
# Processing Record 196 | Lashio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=lashio
# Processing Record 197 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=belaya gora
# City not found. Skipping...
# Processing Record 198 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=thompson
# Processing Record 199 | Martapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=martapura
# Processing Record 200 | Berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=berdigestyakh
# Processing Record 201 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=broome
# Processing Record 202 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=constitucion
# Processing Record 203 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bathsheba
# Processing Record 204 | Mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=mogadishu
# Processing Record 205 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kruisfontein
# Processing Record 206 | Ulagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ulagan
# City not found. Skipping...
# Processing Record 207 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=geraldton
# Processing Record 208 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sitka
# Processing Record 209 | Arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=arman
# Processing Record 210 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=port lincoln
# Processing Record 211 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=chokurdakh
# Processing Record 212 | Russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=russell
# Processing Record 213 | Jinzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=jinzhou
# Processing Record 214 | Praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=praia
# Processing Record 215 | Mantua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=mantua
# Processing Record 216 | Prince Rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=prince rupert
# Processing Record 217 | Diu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=diu
# Processing Record 218 | Macas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=macas
# Processing Record 219 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=yellowknife
# City not found. Skipping...
# Processing Record 220 | Monduli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=monduli
# Processing Record 221 | Male
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=male
# Processing Record 222 | Nytva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=nytva
# Processing Record 223 | Yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=yeppoon
# Processing Record 224 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=east london
# Processing Record 225 | Sept-Iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sept-iles
# Processing Record 226 | Sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sechura
# Processing Record 227 | Seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=seoul
# Processing Record 228 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bubaque
# Processing Record 229 | Hay River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=hay river
# Processing Record 230 | Baijiantan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=baijiantan
# Processing Record 231 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=tiksi
# Processing Record 232 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ancud
# Processing Record 233 | Sayhat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sayhat
# Processing Record 234 | Khuzdar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=khuzdar
# Processing Record 235 | Jackson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=jackson
# Processing Record 236 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=necochea
# Processing Record 237 | San Jeronimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=san jeronimo
# Processing Record 238 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=hasaki
# Processing Record 239 | Villa Bruzual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=villa bruzual
# Processing Record 240 | Olga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=olga
# Processing Record 241 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=petropavlovsk-kamchatskiy
# Processing Record 242 | Plettenberg Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=plettenberg bay
# Processing Record 243 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=narsaq
# City not found. Skipping...
# Processing Record 244 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=saldanha
# City not found. Skipping...
# Processing Record 245 | Aketi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=aketi
# Processing Record 246 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=klaksvik
# Processing Record 247 | Parauna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=parauna
# Processing Record 248 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bilma
# Processing Record 249 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=richards bay
# Processing Record 250 | Imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=imbituba
# Processing Record 251 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=arraial do cabo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 252 | Gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=gizo
# Processing Record 253 | Ostersund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ostersund
# Processing Record 254 | Malanje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=malanje
# Processing Record 255 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=hilo
# Processing Record 256 | Katangli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=katangli
# Processing Record 257 | Sal Rei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sal rei
# Processing Record 258 | Murshidabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=murshidabad
# Processing Record 259 | Mailani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=mailani
# Processing Record 260 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=georgetown
# Processing Record 261 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=mehamn
# Processing Record 262 | Liwale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=liwale
# Processing Record 263 | Verkhnyaya Inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=verkhnyaya inta
# City not found. Skipping...
# Processing Record 264 | Hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=hovd
# Processing Record 265 | Wuzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=wuzhou
# Processing Record 266 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=caravelas
# City not found. Skipping...
# Processing Record 267 | Kantemirovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kantemirovka
# Processing Record 268 | Linhares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=linhares
# Processing Record 269 | Kelso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kelso
# Processing Record 270 | Talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=talcahuano
# Processing Record 271 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=vila velha
# Processing Record 272 | Gondanglegi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=gondanglegi
# Processing Record 273 | Ca Mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ca mau
# City not found. Skipping...
# Processing Record 274 | Beshpagir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=beshpagir
# Processing Record 275 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=mar del plata
# Processing Record 276 | Erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=erzin
# Processing Record 277 | Zemio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=zemio
# Processing Record 278 | Mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=mitu
# City not found. Skipping...
# Processing Record 279 | Marfino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=marfino
# City not found. Skipping...
# Processing Record 280 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bilibino
# Processing Record 281 | Cam Ranh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=cam ranh
# Processing Record 282 | Borovskoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=borovskoy
# Processing Record 283 | Kysyl-Syr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kysyl-syr
# Processing Record 284 | Poya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=poya
# Processing Record 285 | Puerto Penasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=puerto penasco
# Processing Record 286 | Markova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=markova
# Processing Record 287 | Alcala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=alcala
# City not found. Skipping...
# Processing Record 288 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=aykhal
# Processing Record 289 | Jiangyou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=jiangyou
# Processing Record 290 | Zyryanskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=zyryanskoye
# Processing Record 291 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=nishihara
# City not found. Skipping...
# Processing Record 292 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=faanui
# Processing Record 293 | Nerchinskiy Zavod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=nerchinskiy zavod
# Processing Record 294 | Amarante
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=amarante
# Processing Record 295 | Turayf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=turayf
# Processing Record 296 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=yulara
# Processing Record 297 | Horasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=horasan
# Processing Record 298 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=paamiut
# Processing Record 299 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=guerrero negro
# Processing Record 300 | Havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=havelock
# Processing Record 301 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ponta do sol
# Processing Record 302 | Great Yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=great yarmouth
# Processing Record 303 | Sterling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sterling
# City not found. Skipping...
# Processing Record 304 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=pangnirtung
# Processing Record 305 | Dickinson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=dickinson
# Processing Record 306 | Kampong Cham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kampong cham
# Processing Record 307 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=san patricio
# Processing Record 308 | Santa Isabel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=santa isabel
# City not found. Skipping...
# Processing Record 309 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=salalah
# Processing Record 310 | Caiaponia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=caiaponia
# Processing Record 311 | Murwillumbah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=murwillumbah
# Processing Record 312 | Cine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=cine
# City not found. Skipping...
# Processing Record 313 | Bronnoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bronnoysund
# Processing Record 314 | Herat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=herat
# City not found. Skipping...
# Processing Record 315 | Maralal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=maralal
# Processing Record 316 | Traiguen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=traiguen
# Processing Record 317 | Goksun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=goksun
# Processing Record 318 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=marzuq
# Processing Record 319 | Palasbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=palasbari
# Processing Record 320 | Pervomayskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=pervomayskoye
# Processing Record 321 | Makinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=makinsk
# Processing Record 322 | Baruun-Urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=baruun-urt
# Processing Record 323 | Santiago del Estero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=santiago del estero
# ...
# Processing Record 479 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kalmunai
# Processing Record 480 | Ekhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ekhabi
# Processing Record 481 | Zalaszentgrot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=zalaszentgrot
# Processing Record 482 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=port hedland
# Processing Record 483 | Ordynskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ordynskoye
# City not found. Skipping...
# Processing Record 484 | Kumluca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kumluca
# Processing Record 485 | Victor Harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=victor harbor
# City not found. Skipping...
# Processing Record 486 | Sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sambava
# Processing Record 487 | Lucea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=lucea
# Processing Record 488 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=gamba
# Processing Record 489 | Sampit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sampit
# Processing Record 490 | Nizhniy Kuranakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=nizhniy kuranakh
# Processing Record 491 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=pacific grove
# Processing Record 492 | Dajabon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=dajabon
# Processing Record 493 | Roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=roebourne
# Processing Record 494 | Totness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=totness
# Processing Record 495 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=lavrentiya
# Processing Record 496 | Fairlie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=fairlie
# Processing Record 497 | Togur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=togur
# Processing Record 498 | Ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ayan
# Processing Record 499 | Alekseyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=alekseyevka
# Processing Record 500 | Gambela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=gambela
# Processing Record 501 | Tandil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=tandil
# Processing Record 502 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=nome
# Processing Record 503 | Samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=samarai
# Processing Record 504 | Pascagoula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=pascagoula
# Processing Record 505 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=touros
# Processing Record 506 | Puerto Suarez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=puerto suarez
# Processing Record 507 | Kamareddi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kamareddi
# Processing Record 508 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=hofn
# City not found. Skipping...
# Processing Record 509 | Georgiyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=georgiyevka
# Processing Record 510 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=rawson
# Processing Record 511 | Aqtobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=aqtobe
# Processing Record 512 | Adet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=adet
# Processing Record 513 | Celestun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=celestun
# Processing Record 514 | Archidona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=archidona
# Processing Record 515 | Thai Binh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=thai binh
# Processing Record 516 | Santa Maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=santa maria
# Processing Record 517 | Bindki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bindki
# Processing Record 518 | Ayr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ayr
# Processing Record 519 | Kampot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kampot
# Processing Record 520 | Jutai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=jutai
# Processing Record 521 | Buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=buchanan
# Processing Record 522 | Harstad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=harstad
# Processing Record 523 | Belyy Yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=belyy yar
# Processing Record 524 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bonavista
# Processing Record 525 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=cockburn town
# Processing Record 526 | Antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=antalaha
# Processing Record 527 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=te anau
# Processing Record 528 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=meulaboh
# Processing Record 529 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=belmonte
# Processing Record 530 | Parabel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=parabel
# Processing Record 531 | Santa Isabel do Rio Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=santa isabel do rio negro
# Processing Record 532 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=luanda
# Processing Record 533 | Santa Rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=santa rosa
# Processing Record 534 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=port-gentil
# Processing Record 535 | Ararat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ararat
# Processing Record 536 | Kurlovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kurlovo
# Processing Record 537 | Dan Khun Thot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=dan khun thot
# Processing Record 538 | Kharp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kharp
# Processing Record 539 | Wundanyi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=wundanyi
# Processing Record 540 | Preobrazheniye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=preobrazheniye
# City not found. Skipping...
# Processing Record 541 | San Policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=san policarpo
# Processing Record 542 | Veinticinco de Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=veinticinco de mayo
# Processing Record 543 | Ayagoz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ayagoz
# Processing Record 544 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=hualmay
# Processing Record 545 | Muli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=muli
# Processing Record 546 | San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=san lucas
# Processing Record 547 | Cap Malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=cap malheureux
# Processing Record 548 | Huambo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=huambo
# Processing Record 549 | Shubarshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=shubarshi
# Processing Record 550 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=tilichiki
# Processing Record 551 | Acari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=acari
# Processing Record 552 | Emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=emerald
# Processing Record 553 | Tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=tabou
# Processing Record 554 | Chiredzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=chiredzi
# Processing Record 555 | Kuryk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kuryk
# Processing Record 556 | Tinqueux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=tinqueux
# Processing Record 557 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=saint-augustin
# Processing Record 558 | Panama City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=panama city
# Processing Record 559 | Manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=manta
# Processing Record 560 | Halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=halifax
# Processing Record 561 | Inndyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=inndyr
# Processing Record 562 | Jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=jalu
# Processing Record 563 | Baghdad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=baghdad
# Processing Record 564 | Riviere-au-Renard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=riviere-au-renard
# Processing Record 565 | Khombole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=khombole
# Processing Record 566 | Shuangyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=shuangyang
# Processing Record 567 | Bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bud
# City not found. Skipping...
# Processing Record 568 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ilulissat
# City not found. Skipping...
# Processing Record 569 | Puerto Ayacucho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=puerto ayacucho
# Processing Record 570 | Wucheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=wucheng
# Processing Record 571 | Sabha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sabha
# Processing Record 572 | Lakatoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=lakatoro
# Processing Record 573 | Ituverava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ituverava
# Processing Record 574 | Formosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=formosa
# Processing Record 575 | Xiongyue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=xiongyue
# Processing Record 576 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=dingle
# Processing Record 577 | Sistranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sistranda
# Processing Record 578 | Raton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=raton
# Processing Record 579 | Tumpat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=tumpat
# City not found. Skipping...
# Processing Record 580 | Sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=sibolga
# Processing Record 581 | Ukiah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=ukiah
# Processing Record 582 | Bumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bumba
# Processing Record 583 | Kyaikkami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=kyaikkami
# Processing Record 584 | Prieska
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=prieska
# Processing Record 585 | Bada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=bada
# Processing Record 586 | Linjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1353764eea303a16eb6c7ab2fa57a5aa&q=linjiang

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          586
# Cloudiness    586
# Country       586
# Date          586
# Humidity      586
# Lat           586
# Lng           586
# Max Temp      586
# Wind Speed    586
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv("output_data/weather_data.csv", index =False, header = True)

# Display data frame head 
weather_data.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Itarema           7      BR  1569278613        80  -2.92  -39.92
# 1    Jamestown           0      AU  1569278614        53 -33.21  138.60
# 2    Cape Town           0      ZA  1569278465        77 -33.93   18.42
# 3  Provideniya          20      RU  1569278616        60  64.42 -173.23
# 4    Mount Isa          75      AU  1569278617        14 -20.73  139.49
#
#    Max Temp  Wind Speed
# 0     77.09       11.10
# 1     55.67        1.79
# 2     60.01       11.41
# 3     39.20        2.24
# 4     71.60        8.05

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.322483077139538
